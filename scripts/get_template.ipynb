# %%
import pandas as pd

df = pd.read_excel('../templates/template.xlsx', sheet_name='Sheet1')
df.head()
print(df.to_csv())
# Out:
# ,Main tasks,marker[main_task]
# 0,,
# 1,,
# 2,,
# 3,Support tasks,marker[support_task]
